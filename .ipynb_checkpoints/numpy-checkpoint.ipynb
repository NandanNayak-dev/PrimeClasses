# %%
import numpy as np

# %%
arr=np.array([[1,2,5],[2,3,4]])
print((arr).shape)
# Out:
# (2, 3)

# %%
arr1=np.ones((2,3),dtype="int64")
print(arr1)
arr2=np.full((3,4),100)
print(arr2)
# Out:
# [[1 1 1]
#  [1 1 1]]
# [[100 100 100 100]
#  [100 100 100 100]
#  [100 100 100 100]]
