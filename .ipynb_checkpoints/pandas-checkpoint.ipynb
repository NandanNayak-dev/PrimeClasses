# %%
import pandas as pd

# %%
info={
    "Name":["Rahul","Harshita","nandna"],
    "cgpa":[9.9,9.8,9.2]
}
df=pd.DataFrame(info)
print(df)

# %%
# Out:
#        Name  cgpa
# 0     Rahul   9.9
# 1  Harshita   9.8
# 2    nandna   9.2
