# %%
import pandas as pd

# %%
df=pd.read_csv("raw_data.csv")
df.isnull().sum()
df.dropna()
df.dropna(axis=1)
df.fillna(0)
df["age"].fillna(df["age"].mean())
cleaned_data=df.copy()
cleaned_data["age"]=cleaned_data["age"].fillna(df["age"].mean())
df.bfill()
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# Handle Duplicate
df[["country","gender"]].duplicated()
df2=df.copy()
df.drop_duplicates()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df=df2

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# Data Types
df.dtypes
df2=df.copy()
df2=df2.fillna(0)
df2["age"]=df2["age"].astype("int64").copy()
df2.dtypes
# Out:
# id           int64
# name        object
# age          int64
# country     object
# gender      object
# income     float64
# dtype: object

# %%
import pandas as pd
df=pd.read_csv("globalAirQuality.csv")
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# 0      50.295  108.938  27.998  6.539  52.568  1.096  108       18.504
# 1      32.083   63.043  36.120  4.021  43.536  1.075   90        5.838
# 2      42.250   82.553  26.935  9.538  23.320  0.977   84       31.833
# 3      30.403   79.951  63.536  7.609  31.369  0.230  158       23.140
# 4      21.083   66.423  38.997  6.919  45.615  1.085   97       13.632
# ...       ...      ...     ...    ...     ...    ...  ...          ...
# 17995  27.899   74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996   2.950   47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997  61.347   72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998  40.722   95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999  25.830   30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 0        70.168       3.725
# 1        80.088       8.969
# 2        62.783       9.650
# 3        89.153       8.956
# 4        76.499       4.017
# ...         ...         ...
# 17995    52.443       7.452
# 17996    85.678       4.496
# 17997    72.311       9.660
# 17998    31.880       2.642
# 17999    59.104       4.403
#
# [18000 rows x 15 columns]

# %%
date_str=pd.Series(["2026-12-31"])
type(date_str.dtypes)
# Out:
# numpy.dtypes.ObjectDType

# %%
# Strings
df=pd.read_csv("raw_data.csv")
df["gender"].str.upper()

df["name"].str.split()
df["country"].str.contains("US")

df["country"].str.contains("india",case=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# Feature Engineering
df2=df.copy()
df2["tax"]=df["income"].apply(lambda x:"20%" if x>=50000 else "10%")
df2
# Out:
#     id          name   age country   gender   income  tax
# 0    1      John Doe  29.0     USA     Male  55000.0  20%
# 1    1      John Doe  29.0     USA     Male  55000.0  20%
# 2    2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3    3          Alex   NaN     USA  Unknown  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5    5        Li Wei  27.0   China     Male  51000.0  20%
# 6    6           NaN  45.0   India   Female  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8    8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10  10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
# map()
df2=df.copy()
gender_map={"Male":"M","Female":"F","Unknown":"U"}
df2["gender"]=df2["gender"].map(gender_map)
df2
# Out:
#     id          name   age country gender   income
# 0    1      John Doe  29.0     USA      M  55000.0
# 1    1      John Doe  29.0     USA      M  55000.0
# 2    2    Jane Smith   NaN  Canada      F  62000.0
# 3    3          Alex   NaN     USA      U  47000.0
# 4    4  Maria Garcia  34.0   Spain      F      NaN
# 5    5        Li Wei  27.0   China      M  51000.0
# 6    6           NaN  45.0   India      F  73000.0
# 7    7    Ahmed Khan  38.0     NaN      M  68000.0
# 8    8    Rachel Lee  29.0     USA      F  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico      M  45000.0
# 10  10   Emily Davis  31.0     USA    NaN  58000.0

# %%
# assign()
df2=df2.assign(new_income=df2["income"]*1.1)

# %%
# replace()
df2["country"]=df2["country"].replace("USA","United States")
df2
# Out:
#     id          name   age        country gender   income  new_income
# 0    1      John Doe  29.0  United States      M  55000.0     60500.0
# 1    1      John Doe  29.0  United States      M  55000.0     60500.0
# 2    2    Jane Smith   NaN         Canada      F  62000.0     68200.0
# 3    3          Alex   NaN  United States      U  47000.0     51700.0
# 4    4  Maria Garcia  34.0          Spain      F      NaN         NaN
# 5    5        Li Wei  27.0          China      M  51000.0     56100.0
# 6    6           NaN  45.0          India      F  73000.0     80300.0
# 7    7    Ahmed Khan  38.0            NaN      M  68000.0     74800.0
# 8    8    Rachel Lee  29.0  United States      F  62000.0     68200.0
# 9    9   Carlos Ruiz   NaN         Mexico      M  45000.0     49500.0
# 10  10   Emily Davis  31.0  United States    NaN  58000.0     63800.0

# %%
df2.columns=["Id","Name","Age","Country","Gender","Income","New_Income"]

# %%
df2.rename(columns={"Income":"Salary"})
# Out:
#     Id          Name   Age        Country Gender   Salary  New_Income
# 0    1      John Doe  29.0  United States      M  55000.0     60500.0
# 1    1      John Doe  29.0  United States      M  55000.0     60500.0
# 2    2    Jane Smith   NaN         Canada      F  62000.0     68200.0
# 3    3          Alex   NaN  United States      U  47000.0     51700.0
# 4    4  Maria Garcia  34.0          Spain      F      NaN         NaN
# 5    5        Li Wei  27.0          China      M  51000.0     56100.0
# 6    6           NaN  45.0          India      F  73000.0     80300.0
# 7    7    Ahmed Khan  38.0            NaN      M  68000.0     74800.0
# 8    8    Rachel Lee  29.0  United States      F  62000.0     68200.0
# 9    9   Carlos Ruiz   NaN         Mexico      M  45000.0     49500.0
# 10  10   Emily Davis  31.0  United States    NaN  58000.0     63800.0

# %%
df2.rename(index={1:"First"})
# Out:
#        Id          Name   Age        Country Gender   Income  New_Income
# 0       1      John Doe  29.0  United States      M  55000.0     60500.0
# First   1      John Doe  29.0  United States      M  55000.0     60500.0
# 2       2    Jane Smith   NaN         Canada      F  62000.0     68200.0
# 3       3          Alex   NaN  United States      U  47000.0     51700.0
# 4       4  Maria Garcia  34.0          Spain      F      NaN         NaN
# 5       5        Li Wei  27.0          China      M  51000.0     56100.0
# 6       6           NaN  45.0          India      F  73000.0     80300.0
# 7       7    Ahmed Khan  38.0            NaN      M  68000.0     74800.0
# 8       8    Rachel Lee  29.0  United States      F  62000.0     68200.0
# 9       9   Carlos Ruiz   NaN         Mexico      M  45000.0     49500.0
# 10     10   Emily Davis  31.0  United States    NaN  58000.0     63800.0

# %%
# sort values
sorted_df=df2.sort_values(["Income","Age"],ascending=False)
df2
# Out:
#     Id          Name   Age        Country Gender   Income  New_Income
# 0    1      John Doe  29.0  United States      M  55000.0     60500.0
# 1    1      John Doe  29.0  United States      M  55000.0     60500.0
# 2    2    Jane Smith   NaN         Canada      F  62000.0     68200.0
# 3    3          Alex   NaN  United States      U  47000.0     51700.0
# 4    4  Maria Garcia  34.0          Spain      F      NaN         NaN
# 5    5        Li Wei  27.0          China      M  51000.0     56100.0
# 6    6           NaN  45.0          India      F  73000.0     80300.0
# 7    7    Ahmed Khan  38.0            NaN      M  68000.0     74800.0
# 8    8    Rachel Lee  29.0  United States      F  62000.0     68200.0
# 9    9   Carlos Ruiz   NaN         Mexico      M  45000.0     49500.0
# 10  10   Emily Davis  31.0  United States    NaN  58000.0     63800.0

# %%
# rank()
sorted_df["Ranking"]=sorted_df["Income"].rank(ascending=False,method="dense")

# %%
sorted_df[["Id","Name","Age","Country","Gender","New_Income","Income"]]
# Out:
#     Id          Name   Age        Country Gender  New_Income   Income
# 6    6           NaN  45.0          India      F     80300.0  73000.0
# 7    7    Ahmed Khan  38.0            NaN      M     74800.0  68000.0
# 8    8    Rachel Lee  29.0  United States      F     68200.0  62000.0
# 2    2    Jane Smith   NaN         Canada      F     68200.0  62000.0
# 10  10   Emily Davis  31.0  United States    NaN     63800.0  58000.0
# 0    1      John Doe  29.0  United States      M     60500.0  55000.0
# 1    1      John Doe  29.0  United States      M     60500.0  55000.0
# 5    5        Li Wei  27.0          China      M     56100.0  51000.0
# 3    3          Alex   NaN  United States      U     51700.0  47000.0
# 9    9   Carlos Ruiz   NaN         Mexico      M     49500.0  45000.0
# 4    4  Maria Garcia  34.0          Spain      F         NaN      NaN

# %%
# Assignment:Add id column at the end
df2=df.copy()
new_col_order=[col for col in df2.columns if col!="id"]+["id"]
print(new_col_order)
df2[new_col_order]
# Out:
# ['name', 'age', 'country', 'gender', 'income', 'id']
#             name   age country   gender   income  id
# 0       John Doe  29.0     USA     Male  55000.0   1
# 1       John Doe  29.0     USA     Male  55000.0   1
# 2     Jane Smith   NaN  Canada   Female  62000.0   2
# 3           Alex   NaN     USA  Unknown  47000.0   3
# 4   Maria Garcia  34.0   Spain   Female      NaN   4
# 5         Li Wei  27.0   China     Male  51000.0   5
# 6            NaN  45.0   India   Female  73000.0   6
# 7     Ahmed Khan  38.0     NaN     Male  68000.0   7
# 8     Rachel Lee  29.0     USA   Female  62000.0   8
# 9    Carlos Ruiz   NaN  Mexico     Male  45000.0   9
# 10   Emily Davis  31.0     USA      NaN  58000.0  10

# %%
# Write to CSV
df2=df.copy()
df2=df2.drop_duplicates()
df2=df2.fillna(0)
df2=df2.sort_values("income")
df2=df2.reset_index(drop=True)
df2.to_csv("sorted_data.csv")

# %%
df2
# Out:
#    id          name   age country   gender   income
# 0   4  Maria Garcia  34.0   Spain   Female      0.0
# 1   9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 2   3          Alex   0.0     USA  Unknown  47000.0
# 3   5        Li Wei  27.0   China     Male  51000.0
# 4   1      John Doe  29.0     USA     Male  55000.0
# 5  10   Emily Davis  31.0     USA        0  58000.0
# 6   2    Jane Smith   0.0  Canada   Female  62000.0
# 7   8    Rachel Lee  29.0     USA   Female  62000.0
# 8   7    Ahmed Khan  38.0       0     Male  68000.0
# 9   6             0  45.0   India   Female  73000.0

# %%
# Grouping and Aggregation
df.groupby("country")["income"].mean()
df.groupby("country")["income"].max()

df.groupby("gender")["income"].mean()

# agg()
df.groupby("country")["income"].agg(avg="mean",minimum="min",maximum="max")

df.groupby("country").agg(
    average=("income","mean"),
    max_age=("age","max")
)
# Out:
#          average  max_age
# country
# Canada   62000.0      NaN
# China    51000.0     27.0
# India    73000.0     45.0
# Mexico   45000.0      NaN
# Spain        NaN     34.0
# USA      55400.0     31.0

# %%
# Melt And Pivot
df=pd.DataFrame({
    "country":["USA","USA","India","India"],
    "year":[2020,2021,2020,2021],
    "sales":[100,120,90,110],
    "profit":[20,25,18,22]
})
melted_data=df.melt(
    id_vars=["country","year"],
    value_vars=["sales","profit"],
    var_name="matrics",
    value_name="value"
)
original=melted_data.pivot(
    index=["country","year"],
    columns="matrics",
    values="value"
)
original
# Out:
# matrics       profit  sales
# country year
# India   2020      18     90
#         2021      22    110
# USA     2020      20    100
#         2021      25    120

# %%
df
# Out:
#   country  year  sales  profit
# 0     USA  2020    100      20
# 1     USA  2021    120      25
# 2   India  2020     90      18
# 3   India  2021    110      22

# %%
# Visualization using Pandas
df=pd.read_csv("raw_data.csv")
df["age"].hist()
df.plot(kind="scatter",x="age",y="income")
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
# Joins
df_customers=pd.DataFrame({
    "customer_id":[1,2,3,4],
    "name":["Adam","Bob","Charlie","Dave"]
})

df_orders=pd.DataFrame({
    "order_id":[101,102,103,104],
    "customer_id":[2,1,4,5],
    "amount":[250,120,300,100]
})

# %%
df_customers
# Out:
#    customer_id     name
# 0            1     Adam
# 1            2      Bob
# 2            3  Charlie
# 3            4     Dave

# %%
df_orders
# Out:
#    order_id  customer_id  amount
# 0       101            2     250
# 1       102            1     120
# 2       103            4     300
# 3       104            5     100

# %%
pd.merge(df_customers,df_orders,on="customer_id")

pd.merge(df_customers,df_orders,on="customer_id",how="right")
# Out:
#    customer_id  name  order_id  amount
# 0            2   Bob       101     250
# 1            1  Adam       102     120
# 2            4  Dave       103     300
# 3            5   NaN       104     100

# %%
pd.merge(df_customers,df_orders,on="customer_id",how="left")
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0
